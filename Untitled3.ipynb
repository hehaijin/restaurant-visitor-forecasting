# %%
import sklearn
import numpy as np
import pandas as pd
from datetime import datetime

# %%
training=pd.read_csv("kernel1training.csv")
testing=pd.read_csv("kernel1testing.csv")

# %%
training.head()
# Out:
#            air_store_id  visit_date  visitors  dow  year  month  holiday_flg  \
# 0  air_ba937bf13d40fb24  2016-01-13        25    2  2016      1            0
# 1  air_ba937bf13d40fb24  2016-01-14        32    3  2016      1            0
# 2  air_ba937bf13d40fb24  2016-01-15        29    4  2016      1            0
# 3  air_ba937bf13d40fb24  2016-01-16        22    5  2016      1            0
# 4  air_ba937bf13d40fb24  2016-01-18         6    0  2016      1            0
#
#    min_visitors  mean_visitors  median_visitors      ...        rv2_y  \
# 0           7.0      23.843750             25.0      ...         -1.0
# 1           2.0      20.292308             21.0      ...         -1.0
# 2           4.0      34.738462             35.0      ...         -1.0
# 3           6.0      27.651515             27.0      ...         -1.0
# 4           2.0      13.754386             12.0      ...         -1.0
#
#                                 id  total_reserv_sum  total_reserv_mean  \
# ...

# %%
testing.head()
# Out:
#                                 id   visitors  visit_date  \
# 0  air_00a91d42b08b08d9_2017-04-23   2.584138  2017-04-23
# 1  air_00a91d42b08b08d9_2017-04-24  21.196172  2017-04-24
# 2  air_00a91d42b08b08d9_2017-04-25  23.153406  2017-04-25
# 3  air_00a91d42b08b08d9_2017-04-26  30.322339  2017-04-26
# 4  air_00a91d42b08b08d9_2017-04-27  31.780670  2017-04-27
#
#            air_store_id  dow  year  month  holiday_flg  min_visitors  \
# 0  air_00a91d42b08b08d9    6  2017      4            0           2.0
# 1  air_00a91d42b08b08d9    0  2017      4            0           1.0
# 2  air_00a91d42b08b08d9    1  2017      4            0           1.0
# 3  air_00a91d42b08b08d9    2  2017      4            0          15.0
# 4  air_00a91d42b08b08d9    3  2017      4            0          15.0
#
#    mean_visitors      ...        rs2_y  rv2_y  total_reserv_sum  \
# 0       2.000000      ...         -1.0   -1.0              -1.0
# 1      22.457143      ...         -1.0   -1.0              -1.0
# ...

# %%
train_X=training.drop(["visitors","id"],axis=1)
train_Y=train["visitors"]
test_X=test.drop(["visitors","air_store_id","id"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-10-5edf4f9d81ae> in <module>()
# ----> 1 train_X=train.drop(["visitors","id"],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, level, inplace, errors)
#    2159                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2160             else:
# -> 2161                 new_axis = axis.drop(labels, errors=errors)
#    2162             dropped = self.reindex(**{axis_name: new_axis})
#    2163             try:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    3622             if errors != 'ignore':
#    3623                 raise ValueError('labels %s not contained in axis' %
# -> 3624                                  labels[mask])
#    3625             indexer = indexer[~mask]
# ...

# %%
train_Y=train["visitors"]
test_X=test.drop(["visitors","air_store_id","id"])
